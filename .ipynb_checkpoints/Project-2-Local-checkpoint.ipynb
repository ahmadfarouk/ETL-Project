# %%
import sqlalchemy 
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func,inspect
from sqlalchemy import Integer, Column, Float, String
import numpy as np

# %%
import pandas as pd
import os
import csv
import requests
#from config import api_key
from pprint import pprint
import matplotlib.pyplot as plt

# %%
input_file= os.path.join("TMDB_OMDB-3.csv")
df_new=pd.read_csv('TMDB_OMDB-3.csv', encoding = 'utf8')
df_new.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  80163890  TV Show                                  Apaches
# 3  70304989    Movie                                 Automata
# 4  70304990    Movie                              Good People
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3               Gabe Ibáñez
# 4         Henrik Ruben Genz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Alberto Ammann, Eloy Azorín, Verónica Echegui,...
# 3  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 4  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
#                                           country date_added  \
# 0        United States, India, South Korea, China   9-Sep-19
# 1                                  United Kingdom   9-Sep-16
# 2                                           Spain   8-Sep-17
# 3          Bulgaria, United States, Spain, Canada   8-Sep-17
# 4  United States, United Kingdom, Denmark, Sweden   8-Sep-17
#
#    Netflix release year rating  duration  \
# 0                  2019  TV-PG    90 min
# 1                  2016  TV-MA    94 min
# 2                  2016  TV-MA  1 Season
# 3                  2014      R   110 min
# 4                  2014      R    90 min
#
#                                            listed_in  \
# 0                 Children & Family Movies, Comedies
# 1                                    Stand-Up Comedy
# 2  Crime TV Shows, International TV Shows, Spanis...
# 3  International Movies, Sci-Fi & Fantasy, Thrillers
# 4                      Action & Adventure, Thrillers
#
#                                          description  IMDB rating  \
# 0  Before planning an awesome wedding for his gra...            3
# 1  Jandino Asporaat riffs on the challenges of ra...            5
# 2  A young journalist is forced into a life of cr...            5
# 3  In a dystopian future, an insurance adjuster f...            6
# 4  A struggling couple can't believe their luck w...            5
#
#    Rotten Tomatoes rating           Award Released Date   Budget  Movie ID  \
# 0                      36             NaN      2-Aug-19        0  601131.0
# 1                       0             NaN           NaN        0  415722.0
# 2                      31  2 nominations.     14-Aug-13        0  164337.0
# 3                      29  6 nominations.     17-Oct-14  7000000  262543.0
# 4                      12             NaN     21-Aug-15        0  262338.0
#
#    Revenue
# 0  1442504
# 1        0
# 2        0
# 3        0
# 4        0

# %%
engine = create_engine("postgres://pgadmin@pg-srv-001:ucN-xZRL3NsaBjvG2tcw1gPcsNeS5Xfw@pg-srv-001.postgres.database.azure.com:5432/netflix",connect_args={'sslmode':'require'})

conn=engine.connect()
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['pg_rating', 'title', 'cast', 'Listed_in']

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['pg_rating', 'title', 'director', 'country', 'cast', 'Listed_in']

# %%
title_df = pd.DataFrame(df_new,columns=['show_id','show_type','title','date_added','Netflix release year','duration','description','IMDB rating','Rotten Tomatoes rating','Award','Released Date','Movie ID','Revenue'])

title_df = title_df.reset_index(drop=True)
title_df.head()
# Out:
#     show_id  show_type                                    title date_added  \
# 0  81145628        NaN  Norm of the North: King Sized Adventure   9-Sep-19
# 1  80117401        NaN               Jandino: Whatever it Takes   9-Sep-16
# 2  80163890        NaN                                  Apaches   8-Sep-17
# 3  70304989        NaN                                 Automata   8-Sep-17
# 4  70304990        NaN                              Good People   8-Sep-17
#
#    Netflix release year  duration  \
# 0                  2019    90 min
# 1                  2016    94 min
# 2                  2016  1 Season
# 3                  2014   110 min
# 4                  2014    90 min
#
#                                          description  IMDB rating  \
# 0  Before planning an awesome wedding for his gra...            3
# 1  Jandino Asporaat riffs on the challenges of ra...            5
# 2  A young journalist is forced into a life of cr...            5
# 3  In a dystopian future, an insurance adjuster f...            6
# 4  A struggling couple can't believe their luck w...            5
#
#    Rotten Tomatoes rating           Award Released Date  Movie ID  Revenue
# 0                      36             NaN      2-Aug-19  601131.0  1442504
# 1                       0             NaN           NaN  415722.0        0
# 2                      31  2 nominations.     14-Aug-13  164337.0        0
# 3                      29  6 nominations.     17-Oct-14  262543.0        0
# 4                      12             NaN     21-Aug-15  262338.0        0

# %%
title_df["description"] = title_df["description"].str.replace("'","''")

# %%
field_imp=['show_id' ,'show_type','title','date_added','Netflix release year','duration','description','IMDB rating','Rotten Tomatoes rating','Award','Released Date','Movie ID','Revenue']
for i in field_imp:
    def sql_import(i):

        statement = f"INSERT INTO title (i) VALUES ('{i}')"
        conn.execute(statement)
        
    print(i)
# Out:
# show_id
# show_type
# title
# date_added
# Netflix release year
# duration
# description
# IMDB rating
# Rotten Tomatoes rating
# Award
# Released Date
# Movie ID
# Revenue

# %%
show_id_list = list(title_df['show_id'])
show_type_list = list(title_df['show_type'])
title_list = list(title_df['title'])
date_added_list = list(title_df['date_added'])
Netflix_release_year_list = list(title_df['Netflix release year'])
duration_list = list(title_df['duration'])
description_list = list(title_df['description'])
IMDB_rating_list = list(title_df['IMDB rating'])
Rotten_Tomatoes_rating_list = list(title_df['Rotten Tomatoes rating'])
Award_list = list(title_df['Award'])
Released_Date_list = list(title_df['Released Date'])
Movie_ID_list = list(title_df['Movie ID'])
Revenue_list = list(title_df['Revenue'])
for i in range (len (show_id_list)):
      print (show_id_list,show_type_list,title_list,date_added_list,Netflix_release_year_list,duration_list,description_list,IMDB_rating_list,Rotten_Tomatoes_rating_list,Award_list,Released_Date_list,Movie_ID_list,Revenue_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
Def 
for col1, col2 in title_df.iterrows():
    print(col2)
    #statement = f"INSERT INTO title (show_id,show_type,title,date_added,Netflix release year,duration,description,IMDB rating,Rotten Tomatoes rating,Award,Released Date,Movie ID,Revenue) VALUES ('{cols}')"
    #conn.execute(statement)
# Out:
# show_id                                                            81145628
# show_type                                                               NaN
# title                               Norm of the North: King Sized Adventure
# date_added                                                         9-Sep-19
# Netflix release year                                                   2019
# duration                                                             90 min
# description               Before planning an awesome wedding for his gra...
# IMDB rating                                                               3
# Rotten Tomatoes rating                                                   36
# Award                                                                   NaN
# Released Date                                                      2-Aug-19
# Movie ID                                                             601131
# Revenue                                                             1442504
# Name: 0, dtype: object
# show_id                                                            80117401
# show_type                                                               NaN
# title                                            Jandino: Whatever it Takes
# date_added                                                         9-Sep-16
# Netflix release year                                                   2016
# duration                                                             94 min
# description               Jandino Asporaat riffs on the challenges of ra...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                    0
# Award                                                                   NaN
# Released Date                                                           NaN
# Movie ID                                                             415722
# Revenue                                                                   0
# Name: 1, dtype: object
# show_id                                                            80163890
# show_type                                                               NaN
# title                                                               Apaches
# date_added                                                         8-Sep-17
# Netflix release year                                                   2016
# duration                                                           1 Season
# description               A young journalist is forced into a life of cr...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                   31
# Award                                                        2 nominations.
# Released Date                                                     14-Aug-13
# Movie ID                                                             164337
# Revenue                                                                   0
# Name: 2, dtype: object
# show_id                                                            70304989
# show_type                                                               NaN
# title                                                              Automata
# date_added                                                         8-Sep-17
# Netflix release year                                                   2014
# duration                                                            110 min
# description               In a dystopian future, an insurance adjuster f...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   29
# Award                                                        6 nominations.
# Released Date                                                     17-Oct-14
# Movie ID                                                             262543
# Revenue                                                                   0
# Name: 3, dtype: object
# show_id                                                            70304990
# show_type                                                               NaN
# title                                                           Good People
# date_added                                                         8-Sep-17
# Netflix release year                                                   2014
# duration                                                             90 min
# description               A struggling couple can''t believe their luck ...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                   12
# Award                                                                   NaN
# Released Date                                                     21-Aug-15
# Movie ID                                                             262338
# Revenue                                                                   0
# Name: 4, dtype: object
# show_id                                                            80169755
# show_type                                                               NaN
# title                                           Joaquín Reyes: Una y no más
# date_added                                                         8-Sep-17
# Netflix release year                                                   2017
# duration                                                             78 min
# description               Comedian and celebrity impersonator Joaquín Re...
# IMDB rating                                                               0
# Rotten Tomatoes rating                                                    0
# Award                                                                   NaN
# Released Date                                                           NaN
# Movie ID                                                             474599
# Revenue                                                                   0
# Name: 5, dtype: object
# show_id                                                            70299204
# show_type                                                               NaN
# title                                               Kidnapping Mr. Heineken
# date_added                                                         8-Sep-17
# Netflix release year                                                   2015
# duration                                                             95 min
# description               When beer magnate Alfred "Freddy" Heineken is ...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   19
# Award                                                                   NaN
# Released Date                                                      6-Mar-15
# Movie ID                                                             228968
# Revenue                                                             2633527
# Name: 6, dtype: object
# show_id                                                            80060297
# show_type                                                               NaN
# title                                                     Manhattan Romance
# date_added                                                         8-Sep-17
# Netflix release year                                                   2014
# duration                                                             98 min
# description               A filmmaker working on a documentary about lov...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                   58
# Award                                                               3 wins.
# Released Date                                                      1-Jan-16
# Movie ID                                                             302323
# Revenue                                                                   0
# Name: 7, dtype: object
# show_id                                                            80046728
# show_type                                                               NaN
# title                                                           Moonwalkers
# date_added                                                         8-Sep-17
# Netflix release year                                                   2015
# duration                                                             96 min
# description               A brain-addled war vet, a failing band manager...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   39
# Award                                                                   NaN
# Released Date                                                     15-Jan-16
# Movie ID                                                             272548
# Revenue                                                                   0
# Name: 8, dtype: object
# show_id                                                            80046727
# show_type                                                               NaN
# title                                                        Rolling Papers
# date_added                                                         8-Sep-17
# Netflix release year                                                   2015
# duration                                                             79 min
# description               As the newspaper industry takes a hit, The Den...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   58
# Award                                                                1 win.
# Released Date                                                     19-Feb-16
# Movie ID                                                             324300
# Revenue                                                                   0
# Name: 9, dtype: object
# show_id                                                            70304988
# show_type                                                               NaN
# title                                                    Stonehearst Asylum
# date_added                                                         8-Sep-17
# Netflix release year                                                   2014
# duration                                                            113 min
# description               In 1899, a young doctor arrives at an asylum f...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   54
# Award                                                 1 win & 1 nomination.
# Released Date                                                     24-Oct-14
# Movie ID                                                             207933
# Revenue                                                                   0
# Name: 10, dtype: object
# show_id                                                            80057700
# show_type                                                               NaN
# title                                                            The Runner
# date_added                                                         8-Sep-17
# Netflix release year                                                   2015
# duration                                                             90 min
# description               A New Orleans politician finds his idealistic ...
# IMDB rating                                                               4
# Rotten Tomatoes rating                                                   24
# Award                                                                   NaN
# Released Date                                                      7-Aug-15
# Movie ID                                                             277546
# Revenue                                                                   0
# Name: 11, dtype: object
# show_id                                                            80045922
# show_type                                                               NaN
# title                                                               6 Years
# date_added                                                         8-Sep-15
# Netflix release year                                                   2015
# duration                                                             80 min
# description               As a volatile young couple who have been toget...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                   69
# Award                                                        4 nominations.
# Released Date                                                     18-Aug-15
# Movie ID                                                             323674
# Revenue                                                                   0
# Name: 12, dtype: object
# show_id                                                            80203094
# show_type                                                               NaN
# title                                                           City of Joy
# date_added                                                         7-Sep-18
# Netflix release year                                                   2018
# duration                                                             77 min
# description               Women who''ve been sexually brutalized in war-...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   53
# Award                                                         1 nomination.
# Released Date                                                     17-Apr-92
# Movie ID                                                              47821
# Revenue                                                            14683921
# Name: 13, dtype: object
# show_id                                                            80190843
# show_type                                                               NaN
# title                                                        First and Last
# date_added                                                         7-Sep-18
# Netflix release year                                                   2018
# duration                                                           1 Season
# description               Take an intimate look at the emotionally charg...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                    0
# Award                                                                   NaN
# Released Date                                                      7-Sep-18
# Movie ID                                                              59131
# Revenue                                                                   0
# Name: 14, dtype: object
# show_id                                                            70241607
# show_type                                                               NaN
# title                                                             Laddaland
# date_added                                                         7-Sep-18
# Netflix release year                                                   2011
# duration                                                            112 min
# description               When a family moves into an upscale housing de...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   43
# Award                                               6 wins & 8 nominations.
# Released Date                                                     28-Apr-11
# Movie ID                                                              64215
# Revenue                                                                   0
# Name: 15, dtype: object
# show_id                                                            80988892
# show_type                                                               NaN
# title                                                              Next Gen
# date_added                                                         7-Sep-18
# Netflix release year                                                   2018
# duration                                                            106 min
# description               When lonely Mai forms an unlikely bond with a ...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   80
# Award                                                1 win & 5 nominations.
# Released Date                                                      7-Sep-18
# Movie ID                                                             523777
# Revenue                                                                   0
# Name: 16, dtype: object
# show_id                                                            80159586
# show_type                                                               NaN
# title                              The Most Assassinated Woman in the World
# date_added                                                         7-Sep-18
# Netflix release year                                                   2018
# duration                                                            102 min
# description               In 1930s Paris, an actress famous for her gory...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                    0
# Award                                                         1 nomination.
# Released Date                                                      7-Sep-18
# Movie ID                                                             478100
# Revenue                                                                   0
# Name: 17, dtype: object
# show_id                                                            81154455
# show_type                                                               NaN
# title                                                            Article 15
# date_added                                                         6-Sep-19
# Netflix release year                                                   2019
# duration                                                            125 min
# description               The grim realities of caste discrimination com...
# IMDB rating                                                               8
# Rotten Tomatoes rating                                                   89
# Award                                             14 wins & 18 nominations.
# Released Date                                                     28-Jun-19
# Movie ID                                                             597089
# Revenue                                                                   0
# Name: 18, dtype: object
# show_id                                                            81052275
# show_type                                                               NaN
# title                                                 Ee Nagaraniki Emaindi
# date_added                                                         6-Sep-19
# Netflix release year                                                   2018
# duration                                                            133 min
# description               In Goa and in desperate need of cash, four chi...
# IMDB rating                                                               7
# Rotten Tomatoes rating                                                    0
# Award                                                                   NaN
# Released Date                                                     28-Jun-18
# Movie ID                                                             532789
# Revenue                                                                   0
# Name: 19, dtype: object
# show_id                                                            80162141
# show_type                                                               NaN
# title                                                             Hard Tide
# date_added                                                         6-Sep-17
# Netflix release year                                                   2015
# duration                                                             79 min
# description               A drug dealer who''s been emulating his father...
# IMDB rating                                                               4
# Rotten Tomatoes rating                                                  100
# Award                                                                   NaN
# Released Date                                                     29-Apr-16
# Movie ID                                                             395235
# Revenue                                                                   0
# Name: 20, dtype: object
# show_id                                                            80095641
# show_type                                                               NaN
# title                                                          Elstree 1976
# date_added                                                         6-Sep-16
# Netflix release year                                                   2015
# duration                                                            102 min
# description               Then and now footage of bit players who appear...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                   81
# Award                                                                   NaN
# Released Date                                                      6-May-16
# Movie ID                                                             322506
# Revenue                                                                   0
# Name: 21, dtype: object
# show_id                                                            80159880
# show_type                                                               NaN
# title                                                                   ATM
# date_added                                                         5-Sep-18
# Netflix release year                                                   2012
# duration                                                            122 min
# description               When a broken ATM dishes out a fortune, a coup...
# IMDB rating                                                               4
# Rotten Tomatoes rating                                                   12
# Award                                                                   NaN
# Released Date                                                      2-Mar-12
# Movie ID                                                              89691
# Revenue                                                                3010
# Name: 22, dtype: object
# show_id                                                            70184051
# show_type                                                               NaN
# title                                                               One Day
# date_added                                                        16-Dec-18
# Netflix release year                                                   2011
# duration                                                            107 min
# description               After a brief college romance, Emma and Dexter...
# IMDB rating                                                               7
# Rotten Tomatoes rating                                                   36
# Award                                                1 win & 2 nominations.
# Released Date                                                     19-Aug-11
# Movie ID                                                              51828
# Revenue                                                            59389433
# Name: 23, dtype: object
# show_id                                                            70142798
# show_type                                                               NaN
# title                                                              Phobia 2
# date_added                                                         5-Sep-18
# Netflix release year                                                   2009
# duration                                                            125 min
# description               From disfiguring punishments to festering soul...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   58
# Award                                                        5 nominations.
# Released Date                                                     24-Sep-09
# Movie ID                                                              37963
# Revenue                                                             5030049
# Name: 24, dtype: object
# show_id                                                            80147760
# show_type                                                               NaN
# title                                                          Carrie Pilby
# date_added                                                         5-Sep-17
# Netflix release year                                                   2016
# duration                                                             98 min
# description               A socially awkward 19-year-old genius makes bi...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   62
# Award                                                1 win & 2 nominations.
# Released Date                                                      4-Apr-17
# Movie ID                                                             317560
# Revenue                                                               28430
# Name: 25, dtype: object
# show_id                                                            80177405
# show_type                                                               NaN
# title                                                  Marc Maron: Too Real
# date_added                                                         5-Sep-17
# Netflix release year                                                   2017
# duration                                                             70 min
# description               Battle-scarred stand-up comedian Marc Maron un...
# IMDB rating                                                               7
# Rotten Tomatoes rating                                                   80
# Award                                                                   NaN
# Released Date                                                      5-Sep-17
# Movie ID                                                             474155
# Revenue                                                                   0
# Name: 26, dtype: object
# show_id                                                            81173255
# show_type                                                               NaN
# title                                                          The Heretics
# date_added                                                         4-Sep-19
# Netflix release year                                                   2017
# duration                                                             88 min
# description               A withdrawn young woman hunted by a malicious ...
# IMDB rating                                                               4
# Rotten Tomatoes rating                                                    0
# Award                                                5 wins & 1 nomination.
# Released Date                                                      1-Nov-17
# Movie ID                                                             438736
# Revenue                                                                   0
# Name: 27, dtype: object
# show_id                                                            81078908
# show_type                                                               NaN
# title                                                     The World We Make
# date_added                                                         4-Sep-19
# Netflix release year                                                   2019
# duration                                                            108 min
# description               A teenage equestrian and a local football play...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                   56
# Award                                                                   NaN
# Released Date                                                     27-Jul-19
# Movie ID                                                             606755
# Revenue                                                                   0
# Name: 28, dtype: object
# show_id                                                            80201906
# show_type                                                               NaN
# title                                                         Black Panther
# date_added                                                         4-Sep-18
# Netflix release year                                                   2018
# duration                                                            135 min
# description               T''Challa, the superpowered new leader of the ...
# IMDB rating                                                               7
# Rotten Tomatoes rating                                                   96
# Award                     Won 3 Oscars. Another 109 wins & 265 nominations.
# Released Date                                                     16-Feb-18
# Movie ID                                                             284054
# Revenue                                                          1346739107
# Name: 29, dtype: object
# show_id                                                            80052612
# show_type                                                               NaN
# title                                                                Man Up
# date_added                                                         4-Sep-18
# Netflix release year                                                   2015
# duration                                                             88 min
# description               A single woman seizes an opportunity when, whi...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   80
# Award                                                                   NaN
# Released Date                                                     13-Nov-15
# Movie ID                                                             332340
# Revenue                                                             3000000
# Name: 30, dtype: object
# show_id                                                            80113641
# show_type                                                               NaN
# title                                                             Frequency
# date_added                                                         4-Sep-17
# Netflix release year                                                   2016
# duration                                                           1 Season
# description               A detective seizes a precious opportunity to c...
# IMDB rating                                                               7
# Rotten Tomatoes rating                                                   70
# Award                     Nominated for 1 Golden Globe. Another 2 wins &...
# Released Date                                                     28-Apr-00
# Movie ID                                                              10559
# Revenue                                                            68106245
# Name: 31, dtype: object
# show_id                                                            81054495
# show_type                                                               NaN
# title                                                 Mo Gilligan: Momentum
# date_added                                                        30-Sep-19
# Netflix release year                                                   2019
# duration                                                             64 min
# description               Comedian Mo Gilligan blends smooth moves and s...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                    0
# Award                                                                   NaN
# Released Date                                                     30-Sep-19
# Movie ID                                                             635497
# Revenue                                                                   0
# Name: 32, dtype: object
# show_id                                                            70212504
# show_type                                                               NaN
# title                                                           Big Miracle
# date_added                                                        30-Sep-18
# Netflix release year                                                   2012
# duration                                                            107 min
# description               After a reporter writes about whales trapped i...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   75
# Award                                                         1 nomination.
# Released Date                                                      3-Feb-12
# Movie ID                                                              78698
# Revenue                                                            24719215
# Name: 33, dtype: object
# show_id                                                            80081155
# show_type                                                               NaN
# title                                                           Amanda Knox
# date_added                                                        30-Sep-16
# Netflix release year                                                   2016
# duration                                                             92 min
# description               She was twice convicted and acquitted of murde...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   82
# Award                     Nominated for 2 Primetime Emmys. Another 6 nom...
# Released Date                                                     30-Sep-16
# Movie ID                                                             411009
# Revenue                                                                   0
# Name: 34, dtype: object
# show_id                                                            80041601
# show_type                                                               NaN
# title                                                              Lovesick
# date_added                                                  January 1, 2018
# Netflix release year                                                   2018
# duration                                                          3 Seasons
# description               In his quest for true love, Dylan found chlamy...
# IMDB rating                                                               8
# Rotten Tomatoes rating                                                    0
# Award                                                        2 nominations.
# Released Date                                                     15-Apr-15
# Movie ID                                                             319389
# Revenue                                                                   0
# Name: 35, dtype: object
# show_id                                                            80198585
# show_type                                                               NaN
# title                                                    The Debt Collector
# date_added                                                         3-Sep-18
# Netflix release year                                                   2018
# duration                                                             96 min
# description               A broke martial arts instructor takes a side g...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                   83
# Award                                                                   NaN
# Released Date                                                     14-Sep-18
# Movie ID                                                             513691
# Revenue                                                                   0
# Name: 36, dtype: object
# show_id                                                            70233894
# show_type                                                               NaN
# title                                                      Act of Vengeance
# date_added                                                        29-Sep-18
# Netflix release year                                                   2010
# duration                                                            112 min
# description               Two Turkish agents are sent to New York City o...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                   25
# Award                                                                   NaN
# Released Date                                                     18-Aug-74
# Movie ID                                                              32046
# Revenue                                                                   0
# Name: 37, dtype: object
# show_id                                                            80128722
# show_type                                                               NaN
# title                                                         Gerald's Game
# date_added                                                        29-Sep-17
# Netflix release year                                                   2017
# duration                                                            103 min
# description               When her husband''s sex game goes wrong, Jessi...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   91
# Award                                               4 wins & 3 nominations.
# Released Date                                                     29-Sep-17
# Movie ID                                                             343674
# Revenue                                                                   0
# Name: 38, dtype: object
# show_id                                                            80182115
# show_type                                                               NaN
# title                                                             Long Shot
# date_added                                                        29-Sep-17
# Netflix release year                                                   2017
# duration                                                             40 min
# description               When Juan Catalan is arrested for a murder he ...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   81
# Award                                               5 wins & 9 nominations.
# Released Date                                                      3-May-19
# Movie ID                                                             459992
# Revenue                                                            53847136
# Name: 39, dtype: object
# show_id                                                            80104068
# show_type                                                               NaN
# title                                                    Our Souls at Night
# date_added                                                        29-Sep-17
# Netflix release year                                                   2017
# duration                                                            103 min
# description               After widowed neighbors Addie and Louis begin ...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   88
# Award                                                         1 nomination.
# Released Date                                                     29-Sep-17
# Movie ID                                                             433252
# Revenue                                                                   0
# Name: 40, dtype: object
# show_id                                                            80119349
# show_type                                                               NaN
# title                                                       Out of Thin Air
# date_added                                                        29-Sep-17
# Netflix release year                                                   2017
# duration                                                             85 min
# description               Picking up 40 years after six were convicted f...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   47
# Award                                                        2 nominations.
# Released Date                                                      1-May-17
# Movie ID                                                             455479
# Revenue                                                                   0
# Name: 41, dtype: object
# show_id                                                            80019931
# show_type                                                               NaN
# title                                      Monster High: Boo York, Boo York
# date_added                                                        29-Sep-15
# Netflix release year                                                   2015
# duration                                                             72 min
# description               Cleo is invited to a gala in the big city cele...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   82
# Award                                                         1 nomination.
# Released Date                                                     29-Sep-15
# Movie ID                                                             360404
# Revenue                                                                   0
# Name: 42, dtype: object
# show_id                                                            81053893
# show_type                                                               NaN
# title                     Cultivating the Seas: History and Future of th...
# date_added                                                        28-Sep-19
# Netflix release year                                                   2019
# duration                                                             45 min
# description               An in-depth look at the full-cycle breeding pr...
# IMDB rating                                                               0
# Rotten Tomatoes rating                                                    0
# Award                                                                   NaN
# Released Date                                                           NaN
# Movie ID                                                             648825
# Revenue                                                                   0
# Name: 43, dtype: object
# show_id                                                            80200087
# show_type                                                               NaN
# title                                                                Domino
# date_added                                                        28-Sep-19
# Netflix release year                                                   2019
# duration                                                             89 min
# description               A Copenhagen police officer hunts for the man ...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                   36
# Award                                                               2 wins.
# Released Date                                                     14-Oct-05
# Movie ID                                                               9923
# Revenue                                                            22944502
# Name: 44, dtype: object
# show_id                                                            80157072
# show_type                                                               NaN
# title                                                         Hold the Dark
# date_added                                                        28-Sep-18
# Netflix release year                                                   2018
# duration                                                            126 min
# description               In the grim Alaskan winter, a naturalist hunts...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                   71
# Award                                                                1 win.
# Released Date                                                     28-Sep-18
# Movie ID                                                             395841
# Revenue                                                                   0
# Name: 45, dtype: object
# show_id                                                            80992039
# show_type                                                               NaN
# title                                                        Two Catalonias
# date_added                                                        28-Sep-18
# Netflix release year                                                   2018
# duration                                                            117 min
# description               Lawmakers and activists with conflicting ideol...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                    0
# Award                                                                   NaN
# Released Date                                                     28-Sep-18
# Movie ID                                                             549599
# Revenue                                                                   0
# Name: 46, dtype: object
# show_id                                                            80126507
# show_type                                                               NaN
# title                                                  Bobby Sands: 66 Days
# date_added                                                        28-Sep-17
# Netflix release year                                                   2016
# ...
# Rotten Tomatoes rating                                                   67
# Award                                               9 wins & 5 nominations.
# Released Date                                                      4-Aug-17
# Movie ID                                                             402464
# Revenue                                                                   0
# Name: 2663, dtype: object
# show_id                                                            80039655
# show_type                                                               NaN
# title                                     Mike Epps: Don't Take It Personal
# date_added                                                        18-Dec-15
# Netflix release year                                                   2015
# duration                                                             60 min
# description               Mike Epps tears up the stage at L.A.''s histor...
# IMDB rating                                                               4
# Rotten Tomatoes rating                                                    0
# Award                                                                   NaN
# Released Date                                                     18-Dec-15
# Movie ID                                                             371084
# Revenue                                                                   0
# Name: 2664, dtype: object
# show_id                                                            81070659
# show_type                                                               NaN
# title                        Ronny Chieng: Asian Comedian Destroys America!
# date_added                                                        17-Dec-19
# Netflix release year                                                   2019
# duration                                                             63 min
# description               Ronny Chieng ("The Daily Show," "Crazy Rich As...
# IMDB rating                                                               7
# Rotten Tomatoes rating                                                    0
# Award                                                                   NaN
# Released Date                                                     17-Dec-19
# Movie ID                                                             649802
# Revenue                                                                   0
# Name: 2665, dtype: object
# show_id                                                            80039602
# show_type                                                               NaN
# title                                                            Skin Trade
# date_added                                                        17-Dec-18
# Netflix release year                                                   2014
# duration                                                             96 min
# description               A New Jersey detective whose family was killed...
# IMDB rating                                                               5
# Rotten Tomatoes rating                                                   25
# Award                                                                   NaN
# Released Date                                                     23-Apr-15
# Movie ID                                                             327833
# Revenue                                                                   0
# Name: 2666, dtype: object
# show_id                                                            80090672
# show_type                                                               NaN
# title                                                   Bob's Broken Sleigh
# date_added                                                        17-Dec-15
# Netflix release year                                                   2015
# duration                                                             47 min
# description               An overly eager elf improves Santa''s sleigh, ...
# IMDB rating                                                               4
# Rotten Tomatoes rating                                                   50
# Award                                                                1 win.
# Released Date                                                      1-Dec-15
# Movie ID                                                             372449
# Revenue                                                                   0
# Name: 2667, dtype: object
# show_id                                                            70137790
# show_type                                                               NaN
# title                                                             Burlesque
# date_added                                                        16-Dec-19
# Netflix release year                                                   2010
# duration                                                            119 min
# description               After leaving Iowa with stars in her eyes, Ali...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   37
# Award                     Won 1 Golden Globe. Another 5 wins & 19 nomina...
# Released Date                                                     24-Nov-10
# Movie ID                                                              42297
# Revenue                                                            89519773
# Name: 2668, dtype: object
# show_id                                                            81048551
# show_type                                                               NaN
# title                                                Sincerely Yours, Dhaka
# date_added                                                        16-Dec-19
# Netflix release year                                                   2018
# duration                                                            136 min
# description               Eleven emerging Bangladeshi filmmakers present...
# IMDB rating                                                               0
# Rotten Tomatoes rating                                                    0
# Award                                                                   NaN
# Released Date                                                           NaN
# Movie ID                                                             603557
# Revenue                                                                   0
# Name: 2669, dtype: object
# show_id                                                            80058477
# show_type                                                               NaN
# title                                                       The Danish Girl
# date_added                                                        16-Dec-19
# Netflix release year                                                   2015
# duration                                                            120 min
# description               In 1920s Denmark, married artists embark on a ...
# IMDB rating                                                               7
# Rotten Tomatoes rating                                                   67
# Award                        Won 1 Oscar. Another 31 wins & 76 nominations.
# Released Date                                                     22-Jan-16
# Movie ID                                                             306819
# Revenue                                                            64191523
# Name: 2670, dtype: object
# show_id                                                            81000861
# show_type                                                               NaN
# title                                                 American Circumcision
# date_added                                                        16-Dec-18
# Netflix release year                                                   2017
# duration                                                            101 min
# description               With interviews from experts on both sides of ...
# IMDB rating                                                               7
# Rotten Tomatoes rating                                                    0
# Award                                                                   NaN
# Released Date                                                     11-Nov-17
# Movie ID                                                             534598
# Revenue                                                                   0
# Name: 2671, dtype: object
# show_id                                                            81039381
# show_type                                                               NaN
# title                                                             Andhadhun
# date_added                                                        16-Dec-18
# Netflix release year                                                   2018
# duration                                                            137 min
# description               A visually impaired pianist’s world careens in...
# IMDB rating                                                               8
# Rotten Tomatoes rating                                                  100
# Award                                             25 wins & 25 nominations.
# Released Date                                                      5-Oct-18
# Movie ID                                                             534780
# Revenue                                                            40000000
# Name: 2672, dtype: object
# show_id                                                            80013772
# show_type                                                               NaN
# title                                                    Kill the Messenger
# date_added                                                        16-Dec-18
# Netflix release year                                                   2014
# duration                                                            112 min
# description               In the 1980s, a crusading journalist uncovers ...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   77
# Award                                               3 wins & 6 nominations.
# Released Date                                                      9-Oct-14
# Movie ID                                                             245916
# Revenue                                                             5218973
# Name: 2673, dtype: object
# show_id                                                            80013474
# show_type                                                               NaN
# title                                                     Maps to the Stars
# date_added                                                        16-Dec-18
# Netflix release year                                                   2014
# duration                                                            112 min
# description               A showbiz family revolving around its teen cel...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   61
# Award                     Nominated for 1 Golden Globe. Another 10 wins ...
# Released Date                                                     27-Feb-15
# Movie ID                                                             157851
# Revenue                                                             1338365
# Name: 2674, dtype: object
# show_id                                                            80000644
# show_type                                                               NaN
# title                                              The Theory of Everything
# date_added                                                        16-Dec-18
# Netflix release year                                                   2014
# duration                                                            123 min
# description               As his esteem grows in the world of physics, S...
# IMDB rating                                                               7
# Rotten Tomatoes rating                                                   80
# Award                       Won 1 Oscar. Another 24 wins & 123 nominations.
# Released Date                                                     26-Nov-14
# Movie ID                                                             266856
# Revenue                                                           123726688
# Name: 2675, dtype: object
# show_id                                                            80127459
# show_type                                                               NaN
# title                                                         Sister Cities
# date_added                                                        16-Dec-16
# Netflix release year                                                   2016
# duration                                                             88 min
# description               After years of estrangement, four sisters gath...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   81
# Award                                                                   NaN
# Released Date                                                     17-Sep-16
# Movie ID                                                             348611
# Revenue                                                                   0
# Name: 2676, dtype: object
# show_id                                                            80101609
# show_type                                                               NaN
# title                                                        Theo Who Lived
# date_added                                                        16-Dec-16
# Netflix release year                                                   2016
# duration                                                             86 min
# description               American journalist Theo Padnos retraces the M...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   83
# Award                                                                1 win.
# Released Date                                                     30-Sep-16
# Movie ID                                                             404945
# Revenue                                                                   0
# Name: 2677, dtype: object
# show_id                                                            80125782
# show_type                                                               NaN
# title                                                          A Family Man
# date_added                                                        15-Dec-19
# Netflix release year                                                   2016
# duration                                                            110 min
# description               A ruthless corporate headhunter battles his ri...
# IMDB rating                                                               6
# Rotten Tomatoes rating                                                   13
# Award                                                                1 win.
# Released Date                                                     28-Jul-17
# Movie ID                                                             375183
# Revenue                                                                   0
# Name: 2678, dtype: object
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
columns = inspector.get_columns('title')
columns
# Out:
# [{'name': 'show_id',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'show_type',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'title',
#   'type': VARCHAR(length=500),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'director',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'show_cast',
#   'type': VARCHAR(length=800),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'country',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'date_added',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'release_year',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'rating',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'duration',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'listed_in',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'description',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'imdb_rating',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'rotten_tomatoes_rating',
#   'type': INTEGER(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'award',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'released_date',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'budget',
#   'type': DOUBLE_PRECISION(precision=53),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'movie_id',
#   'type': INTEGER(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'revenue',
#   'type': DOUBLE_PRECISION(precision=53),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None}]

# %%
for cols in columns: 
    print(cols['name'], cols['type'])
# Out:
# show_id INTEGER
# show_type VARCHAR(255)
# title VARCHAR(500)
# director VARCHAR(255)
# show_cast VARCHAR(800)
# country VARCHAR(255)
# date_added VARCHAR(255)
# release_year VARCHAR(255)
# rating VARCHAR(255)
# duration VARCHAR(255)
# listed_in VARCHAR(255)
# description VARCHAR(255)
# imdb_rating VARCHAR(255)
# rotten_tomatoes_rating INTEGER
# award VARCHAR(255)
# released_date VARCHAR(255)
# budget DOUBLE PRECISION
# movie_id INTEGER
# revenue DOUBLE PRECISION

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Title = Base.classes.title

# %%
session = Session(engine)

# %%
results = session.query(Title.show_id, Title.award, Title.movie_id).order_by(Title.movie_id.desc()).all()

# %%
print(results)
# Out:
# []

# %%
results_2 = session.query(Title.director).all()
print(results_2)
#Director_df = pd.DataFrame(results_2,columns=['director'])
#prcp_df = prcp_df.set_index("director")
#Director_df.head()
# Out:
# []

# %%
Director_df = pd.DataFrame(results_2,columns=['director'])
#Director_df = Director_df.set_index("director")
Director_df = Director_df.reset_index(drop=True)
Director_df.head()
# Out:
# Empty DataFrame
# Columns: [director]
# Index: []

# %%
from sqlalchemy import insert

# %%
for cols in results_2: 
    print(cols[0])

# %%
engine.execute("Select * from Director").fetchall()
# Out:
# []

# %%
Director_df.director = Director_df.director.str.split(',')
Director_df = Director_df.explode('director').reset_index(drop=True)
Director_df.drop_duplicates(subset=['director'], inplace=True)
Director_df.dropna(subset=['director'],inplace=True)
#Director_df = Director_df[Director_df.director != "None"]
Director_df
# Out:
# Empty DataFrame
# Columns: [director]
# Index: []

# %%
Director_df["director"] = Director_df["director"].str.replace("'","''")

# %%
for cols in Director_df['director']: 
    statement = f"INSERT INTO Director (director_name) VALUES ('{cols}')"
    conn.execute(statement)

# %%
#Country
results_3 = session.query(Title.country).all()
print(results_3)
# Out:
# []

# %%
#Country
Country_df = pd.DataFrame(results_3,columns=['country'])
Country_df = Country_df.reset_index(drop=True)
Country_df.head()
# Out:
# Empty DataFrame
# Columns: [country]
# Index: []

# %%
Country_df.country = Country_df.country.str.split(',')
Country_df = Country_df.explode('country').reset_index(drop=True)
Country_df.drop_duplicates(subset=['country'], inplace=True)
Country_df.dropna(subset=['country'],inplace=True)
#Director_df = Director_df[Director_df.director != "None"]
Country_df
# Out:
# Empty DataFrame
# Columns: [country]
# Index: []

# %%
for h in Country_df['country']: 
    statement_2 = f"INSERT INTO country (country_name) VALUES ('{h}')"
    conn.execute(statement_2)
    #print(col)

# %%
#Rating
results_4 = session.query(Title.rating).all()
print(results_4)

# %%
pg_rating_df = pd.DataFrame(results_4,columns=['rating'])
pg_rating_df = pg_rating_df.reset_index(drop=True)
pg_rating_df.head()

# %%
for cols in results_4:
    print(cols[0])

# %%
engine.execute("Select * from pg_rating").fetchall()

# %%
pg_rating_df.drop_duplicates(subset=['rating'], inplace=True)
pg_rating_df.dropna(subset=['rating'],inplace=True)
pg_rating_df

# %%
for cols in pg_rating_df['rating']:
    statement = f"INSERT INTO pg_rating (pg_rating_name) VALUES ('{cols}')"
    conn.execute(statement)

# %%
######### New Code #######
netflix_titles_path = "TMDB_OMDB.csv"

# Read the mouse data and the study results
netflix_titles = pd.read_csv(netflix_titles_path)
netflix_titles.replace('', np.nan, inplace=True) 
netflix_titles.drop_duplicates(subset=['show_id'], inplace=True)
#netflix_titles.dropna(subset=['Movie ID','director', 'cast', 'country', 'listed_in'], inplace=True)
#netflix_titles = netflix_titles_temp.drop(columns=["Unnamed: 0","Unnamed: 0.1"])

netflix_titles

# %%
netflix_titles_countries = pd.DataFrame ({"Titles": netflix_titles["show_id"],
                                          "Country": netflix_titles["country"]}) 
netflix_titles_countries.Country = netflix_titles_countries.Country.str.split(', ')
netflix_titles_countries = netflix_titles_countries.explode('Country').reset_index(drop=True)
netflix_titles_countries.dropna(subset=['Country'], inplace=True)
netflix_titles_countries.head(30)

# %%
netflix_titles_listed_in = pd.DataFrame ({"Titles": netflix_titles["show_id"],
                                          "Listed_In": netflix_titles["listed_in"]}) 
netflix_titles_listed_in.Listed_In = netflix_titles_listed_in.Listed_In.str.split(', ')
netflix_titles_listed_in = netflix_titles_listed_in.explode('Listed_In').reset_index(drop=True)
netflix_titles_listed_in.dropna(subset=['Listed_In'], inplace=True)
netflix_titles_listed_in.head(30)

# %%
netflix_titles_directors = pd.DataFrame ({"Titles": netflix_titles["show_id"],
                                          "directors": netflix_titles["director"]}) 
netflix_titles_directors.directors = netflix_titles_directors.directors.str.split(', ')
netflix_titles_directors = netflix_titles_directors.explode('directors').reset_index(drop=True)
netflix_titles_directors.dropna(subset=['directors'], inplace=True)
netflix_titles_directors.head(30)

# %%
netflix_titles_Cast = pd.DataFrame ({"Titles": netflix_titles["show_id"],
                                          "Cast": netflix_titles["cast"]}) 
netflix_titles_Cast.Cast = netflix_titles_Cast.Cast.str.split(', ')
netflix_titles_Cast = netflix_titles_Cast.explode('Cast').reset_index(drop=True)
netflix_titles_Cast.dropna(subset=['Cast'], inplace=True)
netflix_titles_Cast.head(30)
