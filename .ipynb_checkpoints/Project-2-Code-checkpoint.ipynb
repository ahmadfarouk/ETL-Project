# %%
import sqlalchemy 
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func,inspect
from sqlalchemy import Integer, Column, Float, String

# %%
import pandas as pd
import os
import csv
import requests
#from config import api_key
from pprint import pprint
import matplotlib.pyplot as plt

url="https://api.themoviedb.org/3/genre/movie/list?api_key=fe5727baa38b3d7c17df99a30f93fb0e&language=en-US&'genres'=0"
responses = []


movie_data = requests.get(url).json()
responses.append(movie_data)
pprint(movie_data)
# Out:
# {'genres': [{'id': 28, 'name': 'Action'},
#             {'id': 12, 'name': 'Adventure'},
#             {'id': 16, 'name': 'Animation'},
#             {'id': 35, 'name': 'Comedy'},
#             {'id': 80, 'name': 'Crime'},
#             {'id': 99, 'name': 'Documentary'},
#             {'id': 18, 'name': 'Drama'},
#             {'id': 10751, 'name': 'Family'},
#             {'id': 14, 'name': 'Fantasy'},
#             {'id': 36, 'name': 'History'},
#             {'id': 27, 'name': 'Horror'},
#             {'id': 10402, 'name': 'Music'},
#             {'id': 9648, 'name': 'Mystery'},
#             {'id': 10749, 'name': 'Romance'},
#             {'id': 878, 'name': 'Science Fiction'},
#             {'id': 10770, 'name': 'TV Movie'},
#             {'id': 53, 'name': 'Thriller'},
#             {'id': 10752, 'name': 'War'},
#             {'id': 37, 'name': 'Western'}]}

# %%
engine = create_engine("postgres://nlfzdwmi:ucN-xZRL3NsaBjvG2tcw1gPcsNeS5Xfw@suleiman.db.elephantsql.com:5432/nlfzdwmi")
"""data=engine.execute ("SELECT * from Title")
for record in data:
    print (record)
"""
conn=engine.connect()
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['title']

# %%
titles=[]
i=0
#input_file= os.path.join("netflix_titles.csv")
df = pd.read_csv('updated_movie_file.csv', encoding='utf8')
df_new=pd.read_csv('TMDB.csv', encoding = 'utf8')
titles=list(df['title'])

# %%
df_new.head()
# Out:
#    Unnamed: 0                                              Title  Budget  \
# 0           0            Norm of the North: King Sized Adventure       0
# 1           1                         Jandino: Whatever it Takes       0
# 2           2  Transformers Prime Beast Hunters: Predacons Ri...       0
# 3           3                                       #realityhigh       0
# 4           4                                            Apaches       0
#
#    Movie ID  Revenue
# 0  601131.0  1442504
# 1  415722.0        0
# 2  268092.0        0
# 3       NaN        0
# 4       NaN        0

# %%
df_new.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df_new.dtypes
# Out:
# Title        object
# Budget        int64
# Movie ID    float64
# Revenue       int64
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0   show_id     type                                    title  \
# 0           0  81145628    Movie  Norm of the North: King Sized Adventure
# 1           1  80117401    Movie               Jandino: Whatever it Takes
# 2           2  70234439  TV Show                       Transformers Prime
# 3           3  80058654  TV Show         Transformers: Robots in Disguise
# 4           4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
# ...

# %%
df_merge = df.merge(df_new, left_on='title', right_on='Title')
df_merge.head()
# Out:
#    Unnamed: 0   show_id     type                                    title  \
# 0           0  81145628    Movie  Norm of the North: King Sized Adventure
# 1           1  80117401    Movie               Jandino: Whatever it Takes
# 2           4  80125979    Movie                             #realityhigh
# 3           5  80163890  TV Show                                  Apaches
# 4           5  80163890  TV Show                                  Apaches
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2          Fernando Lebrija
# 3                       NaN
# 4                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 3  Alberto Ammann, Eloy Azorín, Verónica Echegui,...
# 4  Alberto Ammann, Eloy Azorín, Verónica Echegui,...
#
# ...

# %%
no_dup_data=df_merge.drop_duplicates(subset='show_id', keep= "last")

# %%
no_dup_data.head()
# Out:
#    Unnamed: 0   show_id     type                                    title  \
# 0           0  81145628    Movie  Norm of the North: King Sized Adventure
# 1           1  80117401    Movie               Jandino: Whatever it Takes
# 2           4  80125979    Movie                             #realityhigh
# 4           5  80163890  TV Show                                  Apaches
# 5           6  70304989    Movie                                 Automata
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2          Fernando Lebrija
# 4                       NaN
# 5               Gabe Ibáñez
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 4  Alberto Ammann, Eloy Azorín, Verónica Echegui,...
# 5  Antonio Banderas, Dylan McDermott, Melanie Gri...
#
# ...

# %%
no_dup_data.to_csv("TMDB_OMDB-2.csv")

# %%
no_dup_data_final=no_dup_data.drop_duplicates(subset='Movie ID', keep= "last")

# %%
no_dup_data_final.head()
# Out:
#    Unnamed: 0   show_id     type                                    title  \
# 0           0  81145628    Movie  Norm of the North: King Sized Adventure
# 1           1  80117401    Movie               Jandino: Whatever it Takes
# 4           5  80163890  TV Show                                  Apaches
# 5           6  70304989    Movie                                 Automata
# 7           9  70304990    Movie                              Good People
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 4                       NaN
# 5               Gabe Ibáñez
# 7         Henrik Ruben Genz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 4  Alberto Ammann, Eloy Azorín, Verónica Echegui,...
# 5  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
# ...

# %%
no_dup_data_final.to_csv("TMDB_OMDB-3.csv")

# %%
engine = create_engine('postgres://nlfzdwmi:ucN-xZRL3NsaBjvG2tcw1gPcsNeS5Xfw@suleiman.db.elephantsql.com:5432/nlfzdwmi')

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['director', 'title']

# %%
columns = inspector.get_columns('title')
columns
# Out:
# [{'name': 'show_id',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'show_type',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'title',
#   'type': VARCHAR(length=500),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'director',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'show_cast',
#   'type': VARCHAR(length=800),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'country',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'date_added',
#   'type': VARCHAR(length=255),
#   'nullable': True,
#   'default': None,
# ...

# %%
for cols in columns: 
    print(cols['name'], cols['type'])
# Out:
# show_id INTEGER
# show_type VARCHAR(255)
# title VARCHAR(500)
# director VARCHAR(255)
# show_cast VARCHAR(800)
# country VARCHAR(255)
# date_added VARCHAR(255)
# release_year VARCHAR(255)
# rating VARCHAR(255)
# duration VARCHAR(255)
# listed_in VARCHAR(255)
# description VARCHAR(255)
# imdb_rating VARCHAR(255)
# rotten_tomatoes_rating INTEGER
# award VARCHAR(255)
# released_date VARCHAR(255)
# budget DOUBLE PRECISION
# movie_id INTEGER
# revenue DOUBLE PRECISION

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Title = Base.classes.title

# %%
session = Session(engine)

# %%
results = session.query(Title.show_id, Title.award, Title.movie_id).order_by(Title.movie_id.desc()).all()

# %%
print(results)
# Out:
# [(70153404, 'Won 1 Golden Globe. Another 76 wins & 220 nominations.', None), (80145533, None, 760269), (80138915, None, 758834), (70101375, '7 wins & 7 nominations.', 757839), (80219340, None, 752925), (81034635, None, 750813), (80095532, 'Won 1 Primetime Emmy. Another 8 wins & 38 nominations.', 750214), (80190946, None, 748204), (81045513, None, 744395), (70262831, None, 744080), (80207124, None, 741455), (80230018, None, 732310), (80078197, '6 wins & 12 nominations.', 726664), (81034634, None, 724061), (80106989, '1 win & 16 nominations.', 721771), (80095866, None, 720775), (80201542, '1 nomination.', 720395), (70157294, '11 wins & 21 nominations.', 720335), (80219019, None, 720021), (80212251, '1 nomination.', 716633), (81067757, None, 710647), (81013015, '2 nominations.', 704411), (81055408, '3 wins.', 703931), (81015100, None, 703849), (81020543, None, 703426), (81025403, '7 wins & 17 nominations.', 695875), (80994222, None, 693914), (81030409, None, 693359), (80997862, None, 69
# ...

# %%
results_2 = session.query(Title.director).all()
print(results_2)
#Director_df = pd.DataFrame(results_2,columns=['director'])
#prcp_df = prcp_df.set_index("director")
#Director_df.head()
# Out:
# [('Richard Finn, Tim Maltby',), (None,), (None,), ('Gabe Ibáñez',), ('Henrik Ruben Genz',), ('José Miguel Contreras',), ('Daniel Alfredson',), ("Tom O'Brien",), ('Antoine Bardou-Jacquet',), ('Mitch Dickman',), ('Brad Anderson',), ('Austin Stark',), ('Hannah Fidell',), ('Madeleine Gavin',), (None,), ('Sopon Sukdapisit',), ('Kevin R. Adams, Joe Ksander',), ('Franck Ribière',), ('Anubhav Sinha',), ('Tharun Bhascker',), ('Robert Osman, Nathanael Wiseman',), ('Jon Spira',), ('Mez Tharatorn',), ('Lone Scherfig',), ('Banjong Pisanthanakun, Paween Purikitpanya, Songyos Sugmakanan, Parkpoom Wongpoom, Visute Poolvoralaks',), ('Susan Johnson',), ('Lynn Shelton',), ('Chad Archibald',), ('Brian Baugh',), ('Ryan Coogler',), ('Ben Palmer',), (None,), ('Chris Howe',), ('Ken Kwapis',), ('Troy Miller',), ('Rod Blackhurst, Brian McGinn',), (None,), ('Jesse V. Johnson',), ('Mahsun Kırmızıgül',), ('Mike Flanagan',), ('Jacob LaMendola',), ('Ritesh Batra',), ('Dylan Howitt',), ('William Lau',), ('Mana Yasu
# ...

# %%
Director_df = pd.DataFrame(results_2,columns=['director'])
#Director_df = Director_df.set_index("director")
Director_df = Director_df.reset_index(drop=True)
Director_df.head()
# Out:
#                    director
# 0  Richard Finn, Tim Maltby
# 1                      None
# 2                      None
# 3               Gabe Ibáñez
# 4         Henrik Ruben Genz

# %%
from sqlalchemy import insert

# %%
for cols in results_2: 
    print(cols[0])
# Out:
# Richard Finn, Tim Maltby
# None
# None
# Gabe Ibáñez
# Henrik Ruben Genz
# José Miguel Contreras
# Daniel Alfredson
# Tom O'Brien
# Antoine Bardou-Jacquet
# Mitch Dickman
# Brad Anderson
# Austin Stark
# Hannah Fidell
# Madeleine Gavin
# None
# Sopon Sukdapisit
# Kevin R. Adams, Joe Ksander
# Franck Ribière
# Anubhav Sinha
# Tharun Bhascker
# Robert Osman, Nathanael Wiseman
# Jon Spira
# Mez Tharatorn
# Lone Scherfig
# Banjong Pisanthanakun, Paween Purikitpanya, Songyos Sugmakanan, Parkpoom Wongpoom, Visute Poolvoralaks
# Susan Johnson
# Lynn Shelton
# Chad Archibald
# Brian Baugh
# Ryan Coogler
# Ben Palmer
# None
# Chris Howe
# Ken Kwapis
# Troy Miller
# Rod Blackhurst, Brian McGinn
# None
# Jesse V. Johnson
# Mahsun Kırmızıgül
# Mike Flanagan
# Jacob LaMendola
# Ritesh Batra
# Dylan Howitt
# William Lau
# Mana Yasuda
# Brian De Palma
# Jeremy Saulnier
# Álvaro Longoria, Gerardo Olivares
# Brendan Byrne
# Gupse Özay
# Jim Mickle
# ...

# %%
engine.execute("Select * from Director").fetchall()
# Out:
# [(1, '(81145628,"Richard Finn, Tim Maltby")')]

# %%
Director_df.director = Director_df.director.str.split(',')
Director_df = Director_df.explode('director').reset_index(drop=True)
Director_df.drop_duplicates(subset=['director'], inplace=True)
Director_df.dropna(subset=['director'],inplace=True)
#Director_df = Director_df[Director_df.director != "None"]
Director_df
# Out:
#                    director
# 0              Richard Finn
# 1                Tim Maltby
# 2               Gabe Ibáñez
# 3         Henrik Ruben Genz
# 4     José Miguel Contreras
# ...                     ...
# 2843            Kike Maíllo
# 2844       G.J. Echternkamp
# 2845         Zatella Beatty
# 2846            Glen Winter
# 2847             Ian Barber
#
# [2848 rows x 1 columns]

# %%
Director_df["director"] = Director_df["director"].str.replace("'","''")

# %%
for cols in Director_df['director']: 
    statement = f"INSERT INTO Director (director_name) VALUES ('{cols}')"
    conn.execute(statement)
